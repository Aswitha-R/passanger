# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("passanger.csv")

# %%
df
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1    06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3    04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12-01-2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 994  03-01-2009  2009      3       14869     SLC       87      12966    LGW
# 995  06-01-2003  2003      6       11423     DSM       61      16217    YUL
# 996  12-01-2006  2006     12       11433     DTW       43      16257    YYC
# 997  04-01-2005  2005      4       13495     MSY       72      11032    CUN
# 998  02-01-2001  2001      2       13930     ORD       41      13605    NAS
#
# ...

# %%
df.head(999)
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1    06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3    04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12-01-2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 994  03-01-2009  2009      3       14869     SLC       87      12966    LGW
# 995  06-01-2003  2003      6       11423     DSM       61      16217    YUL
# 996  12-01-2006  2006     12       11433     DTW       43      16257    YYC
# 997  04-01-2005  2005      4       13495     MSY       72      11032    CUN
# 998  02-01-2001  2001      2       13930     ORD       41      13605    NAS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26795 entries, 0 to 26794
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      26795 non-null  object
#  1   Year          26795 non-null  int64
#  2   Month         26795 non-null  int64
#  3   usg_apt_id    26795 non-null  int64
#  4   usg_apt       26795 non-null  object
#  5   usg_wac       26795 non-null  int64
#  6   fg_apt_id     26795 non-null  int64
#  7   fg_apt        26795 non-null  object
#  8   fg_wac        26795 non-null  int64
#  9   airlineid     26795 non-null  int64
#  10  carrier       26377 non-null  object
#  11  carriergroup  26794 non-null  float64
#  12  type          26794 non-null  object
#  13  Scheduled     26794 non-null  float64
#  14  Charter       26794 non-null  float64
#  15  Total         26794 non-null  float64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 3.3+ MB

# %%
df.Year.unique()
# Out:
# array([2014, 2007, 2005, 2003, 2001, 2004, 2008, 2010, 2009, 2002, 2006])

# %%
df.isnull()
# Out:
#        data_dte   Year  Month  usg_apt_id  usg_apt  usg_wac  fg_apt_id  \
# 0         False  False  False       False    False    False      False
# 1         False  False  False       False    False    False      False
# 2         False  False  False       False    False    False      False
# 3         False  False  False       False    False    False      False
# 4         False  False  False       False    False    False      False
# ...         ...    ...    ...         ...      ...      ...        ...
# 26790     False  False  False       False    False    False      False
# 26791     False  False  False       False    False    False      False
# 26792     False  False  False       False    False    False      False
# 26793     False  False  False       False    False    False      False
# 26794     False  False  False       False    False    False      False
#
#        fg_apt  fg_wac  airlineid  carrier  carriergroup   type  Scheduled  \
# ...

# %%
x=df.usg_wac
y=df.Month
a=df.usg_wac
b=df.Month
plt.scatter(x,y)
plt.xlabel('usg_wac')
plt.ylabel('fg_wac')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
x=df.Scheduled
y=df.data_dte
z=df.Charter
plt.scatter(x,y)
plt.scatter(y,z)
plt.scatter(x,z)
plt.legend (["Scheduled","data_dte","charter"], loc='upper right')
plt.show()

# %%
df.plot()

# %%
plt.plot(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.plot(kind='bar')

# %%
df.plot.barh()

# %%
df.plot.bar(stacked=True)

# %%
plt.bar(a,b, label="red Bar" ,color='r')
plt.xlabel("usg_wac")
plt.ylabel("fg_wac")
plt.title("International Report Passengers")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.Month.hist(bins=20)

# %%
plt.hist(a)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df=pd.DataFrame(np.random.randn(10,2),columns=['usg_wac','fg_wac'])
df.plot.box()

# %%
plt.stem(a)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.pie(a)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.polar(a)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
